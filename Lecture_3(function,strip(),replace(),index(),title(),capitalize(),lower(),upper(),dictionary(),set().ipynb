# %% [markdown]
# <a href="https://colab.research.google.com/github/karkichtn/DATA-SCIENCE/blob/main/Lecture_3(function%2Cstrip()%2Creplace()%2Cindex()%2Ctitle()%2Ccapitalize()%2Clower()%2Cupper()%2Cdictionary()%2Cset().ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#function
def fun_name(parameters):
  #body of the function

# %%
def add_(a,b):
  return(a+b)

# %%
# lambda function
x = lambda a, b : b * a
print(x(2, 3))

# %%
st = ""
print(len(st))

st = "anaand adjuubhawdub jabd"
a = st.upper()
print(a)

b = st.lower()
print(b)

c = st.title()                 #sentence ke har first word ko capital karega
print(c)

d = st.capitalize()            #first word ko capotal karta hain bas
print(d)
# Out:
# 0
# ANAAND ADJUUBHAWDUB JABD
# anaand adjuubhawdub jabd
# Anaand Adjuubhawdub Jabd
# Anaand adjuubhawdub jabd

# %%
st = '       Harsh Pratab Singh       '
#strip

st = st.strip()                  #aage or piche ki space ko hata tha hain
print(st)
# Out:
# Harsh Pratab Singh

# %%
a = " today "
b =" weather   "
c="is GooD"

a = a.strip()
b = b.strip()
c = c.strip()

d = a +' ' + b +' ' + c
# print(a +' ' + b +' ' + c)
d = d.title()

d=d.replace('Good', 'Bad')              #replace kar deta hain

e=d.find('Bad')                         #find list pe kaam nahi karega ek ek kar ke gine ga string ko

g=['hii','hello','yola']

f=g.index('hello')                       #index list pe kaam karega.   index error dega agar nahi hoga toh
print(f)

print(d)
print(e)
# Out:
# 1
# Today Weather Is Bad
# 17

# %%
s="hello world"

print(s[1:3])
print(s[::5])
print(s[:5])
# Out:
# el
# h d
# hello

# %%
#set

st={2, 2, 23, 2 ,1}
print(st)
# Out:
# {1, 2, 23}

# %%
dct = {
    "name": ["Ramesh", "Suresh", "mohan", 'madan'],
    "age": 23,
    "occupation": 10,
    "Roll no: ": 25

}
print(dct['name'][0])

#add key
dct['id']=12
print(dct)

#delete
del dct['name']
print(dct)
# Out:
# Ramesh
# {'name': ['Ramesh', 'Suresh', 'mohan', 'madan'], 'age': 23, 'occupation': 10, 'Roll no: ': 25, 'id': 12}
# {'age': 23, 'occupation': 10, 'Roll no: ': 25, 'id': 12}
